# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("result.csv")
df
# Out:
#                    objID  run  rerun  camcol  ...  Err_g  Err_r  Err_i  Err_z
# 0     582093500493070640  756     20       3  ...  0.026  0.027  0.036  0.129
# 1     582093500493073198  756     20       3  ...  0.040  0.048  0.063  0.256
# 2     582093500493070627  756     20       3  ...  0.014  0.012  0.015  0.046
# 3     582093500493070629  756     20       3  ...  0.016  0.014  0.019  0.082
# 4     582093500493072166  756     20       3  ...  0.057  0.062  0.083  0.346
# ...                  ...  ...    ...     ...  ...    ...    ...    ...    ...
# 1225  582093500493073853  756     20       3  ...  0.236  0.158  0.328  0.288
# 1226  582093500493073855  756     20       3  ...  0.233  0.179  0.269  0.513
# 1227  582093500493073858  756     20       3  ...  0.340  0.137  0.089  0.178
# 1228  582093500493073901  756     20       3  ...  0.361  0.237  0.176  0.276
# 1229  582093500493073932  756     20       3  ...  0.368  0.207  0.100  0.183
#
# [1230 rows x 19 columns]

# %%
df[df['type'].isin(['6'])]
# Out:
#                    objID  run  rerun  camcol  ...  Err_g  Err_r  Err_i  Err_z
# 0     582093500493070640  756     20       3  ...  0.026  0.027  0.036  0.129
# 1     582093500493073198  756     20       3  ...  0.040  0.048  0.063  0.256
# 2     582093500493070627  756     20       3  ...  0.014  0.012  0.015  0.046
# 4     582093500493072166  756     20       3  ...  0.057  0.062  0.083  0.346
# 5     582093500493072168  756     20       3  ...  0.073  0.082  0.112  0.120
# ...                  ...  ...    ...     ...  ...    ...    ...    ...    ...
# 1222  582093500493073560  756     20       3  ...  0.191  0.158  0.291  0.653
# 1223  582093500493073562  756     20       3  ...  0.090  0.082  0.122  0.398
# 1224  582093500493073563  756     20       3  ...  0.144  0.111  0.145  0.316
# 1226  582093500493073855  756     20       3  ...  0.233  0.179  0.269  0.513
# 1228  582093500493073901  756     20       3  ...  0.361  0.237  0.176  0.276
#
# [988 rows x 19 columns]

# %%
sns.set_theme()

df["g - r"] = df["g"] - df["r"]

plot = plt.scatter(data=df, y="r", x="g - r", s=2)
plt.gca().invert_yaxis()
plt.gca().set_ylabel("r")
plt.gca().set_xlabel("g - r")
# Out:
# Text(0.5, 0, 'g - r')

# %% [markdown]
# r as magnitude (y-axis)
# g-r as color (x-axis)
